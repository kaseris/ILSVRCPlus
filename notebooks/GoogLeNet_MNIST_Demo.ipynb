# %% [markdown]
# #Introduction
# This notebook was written in Google Colab and you will need to log in with your Google account in order to download the pre-trained model for the evaluation.
#
# ---
#
# *Note 1*: To save the user from the hassle of uploading files, a GitHub repository will be downloaded. Make sure you are always within the `content/ILSVRCPlus` directory.
#
# You can always check your current working directory by using the magic: `%pwd`
#
# ---
#
# *Note 2*: If you are impatient and you don't want to train the model, skip to Section 5 to download the pre-trained model from Google Drive and evaluate it.
#
# Make sure you downloaded the dataset first, from Section 2.

# %%
# %pwd

# %% [markdown]
# ##1. Clone the repository
# First of all, let's clone my repository, that contains the implementations of the models and jump in to the generated directory.

# %%
# !git clone https://github.com/kaseris/ILSVRCPlus.git
# %cd ILSVRCPlus
# Out:
# Cloning into 'ILSVRCPlus'...
# remote: Enumerating objects: 149, done.
# remote: Counting objects: 100% (149/149), done.
# remote: Compressing objects: 100% (109/109), done.
# remote: Total 426 (delta 89), reused 98 (delta 40), pack-reused 277
# Receiving objects: 100% (426/426), 25.33 MiB | 35.19 MiB/s, done.
# Resolving deltas: 100% (238/238), done.
# /content/ILSVRCPlus

# %% [markdown]
# ##2. Download the MNIST dataset
# We download the MNIST dataset and we show some of its samples. The VGG model will be trained on this dataset.

# %%
import keras
from keras.datasets import mnist
import matplotlib.pyplot as plt
(trainX, trainY), (testX, testY) = mnist.load_data()
fig, ax = plt.subplots(5, 5, figsize=(7,7))
for i in range(0, 5):
  for j in range(0, 5):
    ax[i][j].axis('off')
    ax[i][j].imshow(trainX[i + 5 * j, :, :], cmap='gray')
# Out:
# Using TensorFlow backend.
# Downloading data from https://s3.amazonaws.com/img-datasets/mnist.npz
# 11493376/11490434 [==============================] - 1s 0us/step

# %% [markdown]
# ##3. Train the model
# In this cell, we import and instantiate a VGG architecture and train on the MNIST dataset. You can skip this step and download the pretrained model from the Google Drive folder:
#
# https://drive.google.com/drive/folders/16AeENomjhIT1C3vmw1fc85xP2SSlZe5z?usp=sharing

# %%
import MiniGoogLeNetMNIST
googlenet = MiniGoogLeNetMNIST.MiniGoogLeNetMNIST()

maxepochs=15
history = googlenet.train(epochs=maxepochs, summary=False)
# Out:
# [INFO]: Downloading dataset
# [INFO]: Compiling model
# [INFO]: ==================MODEL SUMMARY==================
# Model: "Mini GoogLeNet - MNIST"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            (None, 28, 28, 1)    0
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 28, 28, 96)   960         input_2[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 28, 28, 96)   0           conv2d_20[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 28, 28, 32)   3104        activation_21[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 28, 28, 32)   27680       activation_21[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 28, 28, 32)   0           conv2d_21[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 28, 28, 32)   0           conv2d_22[0][0]
# __________________________________________________________________________________________________
# concatenate_11 (Concatenate)    (None, 28, 28, 64)   0           activation_22[0][0]
#                                                                  activation_23[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 28, 28, 32)   2080        concatenate_11[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 28, 28, 32)   18464       concatenate_11[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 28, 28, 32)   0           conv2d_23[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 28, 28, 32)   0           conv2d_24[0][0]
# __________________________________________________________________________________________________
# concatenate_12 (Concatenate)    (None, 28, 28, 64)   0           activation_24[0][0]
#                                                                  activation_25[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 13, 13, 80)   46160       concatenate_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 13, 13, 80)   320         conv2d_25[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 13, 13, 80)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 13, 13, 64)   0           concatenate_12[0][0]
# __________________________________________________________________________________________________
# concatenate_13 (Concatenate)    (None, 13, 13, 144)  0           activation_26[0][0]
#                                                                  max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 13, 13, 112)  16240       concatenate_13[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 13, 13, 112)  145264      concatenate_13[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 13, 13, 112)  0           conv2d_26[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 13, 13, 112)  0           conv2d_27[0][0]
# __________________________________________________________________________________________________
# concatenate_14 (Concatenate)    (None, 13, 13, 224)  0           activation_27[0][0]
#                                                                  activation_28[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 13, 13, 96)   21600       concatenate_14[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 13, 13, 96)   193632      concatenate_14[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 13, 13, 96)   0           conv2d_28[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 13, 13, 96)   0           conv2d_29[0][0]
# __________________________________________________________________________________________________
# concatenate_15 (Concatenate)    (None, 13, 13, 192)  0           activation_29[0][0]
#                                                                  activation_30[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 13, 13, 80)   15440       concatenate_15[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 13, 13, 80)   138320      concatenate_15[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 13, 13, 80)   0           conv2d_30[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 13, 13, 80)   0           conv2d_31[0][0]
# __________________________________________________________________________________________________
# concatenate_16 (Concatenate)    (None, 13, 13, 160)  0           activation_31[0][0]
#                                                                  activation_32[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 13, 13, 48)   7728        concatenate_16[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 13, 13, 48)   69168       concatenate_16[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 13, 13, 48)   0           conv2d_32[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 13, 13, 48)   0           conv2d_33[0][0]
# __________________________________________________________________________________________________
# concatenate_17 (Concatenate)    (None, 13, 13, 96)   0           activation_33[0][0]
#                                                                  activation_34[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 6, 6, 96)     83040       concatenate_17[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 6, 6, 96)     0           conv2d_34[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 6, 6, 96)     0           concatenate_17[0][0]
# __________________________________________________________________________________________________
# concatenate_18 (Concatenate)    (None, 6, 6, 192)    0           activation_35[0][0]
#                                                                  max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 6, 6, 176)    33968       concatenate_18[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 6, 6, 176)    304304      concatenate_18[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 6, 6, 176)    0           conv2d_35[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 6, 6, 176)    0           conv2d_36[0][0]
# __________________________________________________________________________________________________
# concatenate_19 (Concatenate)    (None, 6, 6, 352)    0           activation_36[0][0]
#                                                                  activation_37[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 6, 6, 176)    62128       concatenate_19[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 6, 6, 176)    557744      concatenate_19[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 6, 6, 176)    0           conv2d_37[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 6, 6, 176)    0           conv2d_38[0][0]
# __________________________________________________________________________________________________
# concatenate_20 (Concatenate)    (None, 6, 6, 352)    0           activation_38[0][0]
#                                                                  activation_39[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_2 (AveragePoo (None, 1, 1, 352)    0           concatenate_20[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 1, 1, 352)    0           average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 352)          0           dropout_2[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 10)           3530        flatten_2[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 10)           0           dense_2[0][0]
# ==================================================================================================
# Total params: 1,750,874
# Trainable params: 1,750,714
# Non-trainable params: 160
# __________________________________________________________________________________________________
# [INFO]: Training model
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/15
# 60000/60000 [==============================] - 99s 2ms/step - loss: 1.1065 - accuracy: 0.6838 - val_loss: 0.3530 - val_accuracy: 0.9564
# Epoch 2/15
# 60000/60000 [==============================] - 98s 2ms/step - loss: 0.3621 - accuracy: 0.9545 - val_loss: 0.2752 - val_accuracy: 0.9799
# Epoch 3/15
# 60000/60000 [==============================] - 98s 2ms/step - loss: 0.3159 - accuracy: 0.9680 - val_loss: 0.2795 - val_accuracy: 0.9787
# Epoch 4/15
# 60000/60000 [==============================] - 98s 2ms/step - loss: 0.2926 - accuracy: 0.9746 - val_loss: 0.2672 - val_accuracy: 0.9806
# Epoch 5/15
# 60000/60000 [==============================] - 97s 2ms/step - loss: 0.2796 - accuracy: 0.9786 - val_loss: 0.2489 - val_accuracy: 0.9866
# Epoch 6/15
# 60000/60000 [==============================] - 98s 2ms/step - loss: 0.2683 - accuracy: 0.9813 - val_loss: 0.2408 - val_accuracy: 0.9884
# Epoch 7/15
# 60000/60000 [==============================] - 98s 2ms/step - loss: 0.2622 - accuracy: 0.9831 - val_loss: 0.2396 - val_accuracy: 0.9890
# Epoch 8/15
# 60000/60000 [==============================] - 98s 2ms/step - loss: 0.2561 - accuracy: 0.9845 - val_loss: 0.2339 - val_accuracy: 0.9900
# Epoch 9/15
# 60000/60000 [==============================] - 98s 2ms/step - loss: 0.2507 - accuracy: 0.9859 - val_loss: 0.2314 - val_accuracy: 0.9907
# Epoch 10/15
# 60000/60000 [==============================] - 98s 2ms/step - loss: 0.2447 - accuracy: 0.9870 - val_loss: 0.2334 - val_accuracy: 0.9902
# Epoch 11/15
# 60000/60000 [==============================] - 98s 2ms/step - loss: 0.2436 - accuracy: 0.9878 - val_loss: 0.2272 - val_accuracy: 0.9918
# Epoch 12/15
# 60000/60000 [==============================] - 98s 2ms/step - loss: 0.2397 - accuracy: 0.9887 - val_loss: 0.2290 - val_accuracy: 0.9916
# Epoch 13/15
# 60000/60000 [==============================] - 98s 2ms/step - loss: 0.2379 - accuracy: 0.9888 - val_loss: 0.2250 - val_accuracy: 0.9918
# Epoch 14/15
# 60000/60000 [==============================] - 97s 2ms/step - loss: 0.2361 - accuracy: 0.9900 - val_loss: 0.2237 - val_accuracy: 0.9923
# Epoch 15/15
# 60000/60000 [==============================] - 97s 2ms/step - loss: 0.2345 - accuracy: 0.9901 - val_loss: 0.2237 - val_accuracy: 0.9921

# %% [markdown]
# ##4. Plot the learning curves

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')

plt.figure(figsize=(8,6))
plt.plot(range(maxepochs), history.history['loss'], label='Training loss')
plt.plot(range(maxepochs), history.history['val_loss'], label='Validation loss')
plt.xlabel('# Epoch')
plt.ylabel('Loss')
plt.title('Loss for GoogLeNet variant on MNIST dataset')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.plot(range(maxepochs), history.history['accuracy'], label='Training accuracy')
plt.plot(range(maxepochs), history.history['val_accuracy'], label='Validation accuracy')
plt.xlabel('# Epoch')
plt.ylabel('Accuracy')
plt.title('Accuracy for GoogLeNet variant on MNIST dataset')
plt.legend()
plt.show()

# %% [markdown]
# ##5. Model evaluation

# %% [markdown]
# ###5.1 Evaluate the trained model
# You will be asked to log in with you Google account credentials to get the verification code. The verification code will look like this:
#
# Use Chrome if the image does not appear.
#
# <figure>
# <center>
# <img src="https://drive.google.com/uc?id=1o8yYGesQA6qc9vL8zFr4nz_AuLDe8LFn" width="400">
# </figure>
#
# Copy your code and paste it to the prompt that will pop out after executing the cell below and press Enter.

# %%
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

file_id = "1qYllvULOSwDrXYtg-Anhhcd1bqYc-g3s" # The saved model for the MNIST GoogLeNet
downloaded = drive.CreateFile({'id':file_id})
filename = 'MNISTMiniGoogLeNet-weights-improvement-14-0.99.hdf5'
downloaded.GetContentFile(filename)

# %%
from keras.utils import to_categorical
from keras.models import load_model
import numpy as np
googlenet_mnist = load_model(filename)

try:
  testX = testX.astype(np.float32)
  testX = testX / 255.0
  testX = np.expand_dims(testX, axis=-1)
  testY = to_categorical(testY, 10)
except NameError:
  print("The variable is not defined. Make sure you downloaded the dataset at the second cell.")

# %%
val_loss, val_accuracy = googlenet_mnist.evaluate(testX, testY)
print("Validation loss: {:.3f}\
      Validation accuracy: {:.3f}".format(val_loss, val_accuracy))
# Out:
# 10000/10000 [==============================] - 8s 806us/step
# Validation loss: 0.224      Validation accuracy: 0.992
